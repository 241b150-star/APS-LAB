# %% [markdown]
# <a href="https://colab.research.google.com/github/241b150-star/APS-LAB/blob/main/lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Searching
# Implement Linear Search. Determine the time required to search for element. Repeat the experiment for different values of n, the number of elements in the list to besearched and plot a graph of the time taken versus n.
#
# - To implement Linear Search, measure its time complexity for searching an element, vary the input size by changing the number of elements in the list, and plot a graph to visualize the relationship between time taken and input size
# - Algorithm:
# 1. Start with the first element of the list.
# 2. Compare the element with the value being searched for.
# 3. If the element matches, return the index.
# 4. If the element does not match, move to the next element and repeat steps 2-3.
# 5. If the end of the list is reached and no match is found, return -1

# %% [markdown]
# - **Created by Dr. Ajay

# %%
# write code for Linear Search and plot a graph to visualize the relationship between time taken and input size
import time
import matplotlib.pyplot as plt

# Linear Search function
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1
# Experiment setup
sizes = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
times = []
# Measure time taken for worst-case search (element not present)
for n in sizes:
    arr = list(range(n))
    target = -1  # worst case: not present
    start = time.time()
    linear_search(arr, target)
    end = time.time()
    times.append(end - start)
# Plotting the results
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(10, 6))
plt.plot(sizes, times, marker='o', color='blue', linestyle='-')
plt.xlabel('Number of elements (n)', fontsize=12)
plt.ylabel('Time taken (seconds)', fontsize=12)
plt.title('Linear Search Time vs Input Size', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # 2. Searching
# Implement recursive Binary Search. Determine the time required to search an element.Repeat the experiment for different values of n, the number of elements in the list to besearched and plot a graph of the time taken versus n.
# - implement recursive Binary Search, measure its time complexity for searching an element and plot a graph of time taken versus different values of n, the number of elements in the list.
# Algorithm:
# 1. Start with the middle element of the list
# 2. If the middle element matches the element being searched, return the index of the middle element
# 3. If the middle element is greater than the element being searched, recursively call the function on the left half of the list
# 4. If the middle element  is  less than the element  being searched, recursively call the function on the right half of the list
# 5. If the element is not found, return -1

# %%
#Prob_2: write code for recursive Binary Search and plot a graph to visualize the relationship between time taken and input size
import time
import matplotlib.pyplot as plt
# Recursive Binary Search function
def recursive_binary_search(arr, target, low, high):
    if low > high:
        return -1
    mid = (low + high) // 2
    if arr[mid] == target:
        return mid
    elif arr[mid] > target:
        return recursive_binary_search(arr, target, low, mid - 1)
    else:
        return recursive_binary_search(arr, target, mid + 1, high)
# Experiment setup
sizes = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
times = []
# Measure time taken for worst-case search (element not present)
for n in sizes:
    arr = list(range(n))
    target = -1  # worst case: not present
    start = time.time()
    recursive_binary_search(arr, target, 0, len(arr) - 1)
    end = time.time()
    times.append(end - start)
# Plotting the results
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(10, 6))
plt.plot(sizes, times, marker='o', color='red', linestyle='-')
plt.xlabel('Number of elements (n)', fontsize=12)
plt.ylabel('Time taken (seconds)', fontsize=12)
plt.title('Recursive Binary Search Time vs Input Size', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# #Prob-3
# Given a text txt [0...n-1] and a pattern pat [0...m-1], write a function search (char pat [ ],char txt [ ]) that prints all occurrences of pat [ ] in txt [ ]. You may assume that n > m.
# - Aim:  To write a function "search" that takes a pattern and a text as input, and outputs all occurrences of the pattern in the text.  Algorithm:
# 1. Initialize an empty list to store the indices where the pattern occurs in the text.
# 2. Loop through each character in the text. For each character, check if the substring starting at that character matches the pattern.
# 3. If there is a match, append the starting index of the substring to the list of occurrences.
# 4. Continue looping through the text until all possible substrings have been checked.
# 5. Return the list of indices where the pattern occurs in the text.

# %%
#write code for Prob-3
def search(pat, txt):
    m = len(pat)
    n = len(txt)
    occurrences = []
    # Loop through the text
    for i in range(n - m + 1):
        # Check substring
        if txt[i:i+m] == pat:
            occurrences.append(i)

    return occurrences
# Example usage
txt = "ABABABA"
pat = "ABA"
result = search(pat, txt)
print("Pattern found at indices:", result)
# Out:
# Pattern found at indices: [0, 2, 4]

# %% [markdown]
# #Prob-4
# Sort a given set of elements using the Insertion sort and determine the time required tosort the elements. Repeat the experiment for different values of n, the number of elements in the list to be sorted and plot a graph of the time taken versus n.
# - Aim :  To Develop a program to implement Insertion sort and determine the time required to sort the elements.
# - Algorithm:
# 1. Iterate over the array from the second element to the end (i = 1 to n-1).
# 2. For each element, compare it to the elements before it (j = i-1 to 0).
# 3. If the current element is smaller, swap it with the element before it.
# 4. Repeat step 3 until the current element is no longer smaller than the previous element.
# 5. Repeat steps 2-4 for all elements in the array.

# %%
#Prob_4: write code for insertion sort and plot a graph to visualize the relationship between time taken and input size
import time
import matplotlib.pyplot as plt
import random

# Insertion Sort function
def insertion_sort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
# Experiment setup
sizes = [1000, 2000, 3000, 4000, 5000]
times = []
# Measure time taken for sorting random lists
for n in sizes:
    arr = [random.randint(0, 10000) for _ in range(n)]
    start = time.time()
    insertion_sort(arr)
    end = time.time()
    times.append(end - start)
# Plotting the results
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(10, 6))
plt.plot(sizes, times, marker='o', color='green', linestyle='-')
plt.xlabel('Number of elements (n)', fontsize=12)
plt.ylabel('Time taken (seconds)', fontsize=12)
plt.title('Insertion Sort Time vs Input Size', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Task
# Implement Linear Search, measure its time complexity across different input sizes, and plot a graph showing the relationship between time taken and input size.

# %% [markdown]
# ## Implement Linear Search Function
#
# ### Subtask:
# Write the Python function for Linear Search as described in the algorithm: iterate through the list, compare each element with the target, and return the index if found, otherwise return -1.

# %% [markdown]
# **Reasoning**:
# To implement the linear search function as described in the instructions, I will create a Python code block.

# %%
import time
import matplotlib.pyplot as plt
# Experiment setup
sizes = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
times = []
# Measure time taken for worst-case search (element not present)
for n in sizes:
    arr = list(range(n))
    target = -1  # worst case: not present
    start = time.time()
    linear_search(arr, target)
    end = time.time()
    times.append(end - start)
# Plotting the results
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(10, 6))
plt.plot(sizes, times, marker='o', color='blue', linestyle='-')
plt.xlabel('Number of elements (n)', fontsize=12)
plt.ylabel('Time taken (seconds)', fontsize=12)
plt.title('Linear Search Time vs Input Size', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Measure Time Complexity and Collect Data
#
# **Subtask:** Generate lists of varying sizes, measure the time taken by the `linear_search` function for each list, and store the results for plotting.
#
# #### Instructions
# 1. Import necessary libraries: `time` for measuring execution time and `random` for generating random lists.
# 2. Define a range of input sizes (`n` values), for example, from 100 to 10000 with appropriate steps.
# 3. For each `n`:
#     a. Generate a random list of `n` integers.
#     b. Choose a target element to search for (e.g., a random element from the list or a value not in the list to test worst-case).
#     c. Record the start time.
#     d. Call the `linear_search` function with the generated list and target.
#     e. Record the end time.
#     f. Calculate the time difference (end - start).
#     g. Store `n` and the measured time.
# 4. Store all collected `n` values and corresponding times in separate lists or a dictionary for later plotting.

# %% [markdown]
# **Reasoning**:
# The previous markdown block outlined the steps to measure time complexity. Now, I will implement the Python code to generate lists of varying sizes, run the `linear_search` function, and collect the execution times and corresponding input sizes, preparing this data for plotting.

# %% [markdown]
# ## Execute Data Collection Code
#
# ### Subtask:
# Run the existing Python code to collect data on the time taken by the `linear_search` function for various input sizes. This will generate the `sizes` and `times` lists.

# %% [markdown]
# **Reasoning**:
# The subtask requires running Python code to collect performance data for the `linear_search` function across different input sizes. I will implement the data collection logic as described in the instructions, including importing necessary libraries, generating test data, measuring execution times, and storing the results.

# %%
import time
import random

sizes_to_test = [100, 500, 1000, 2000, 5000, 10000, 20000]
sizes = []
times = []

print("Collecting data...")
for n in sizes_to_test:
    # Generate a random list of n integers
    random_list = [random.randint(0, n * 10) for _ in range(n)]
    target = -1 # A value highly unlikely to be in the list, or we could search for random_list[-1]
    start_time = time.time()
    linear_search(random_list, target)
    end_time = time.time()
    elapsed_time = end_time - start_time
    sizes.append(n)
    times.append(elapsed_time)
print("Data collection complete.")
print(f"Collected input sizes: {sizes}")
print(f"Collected times: {times}")
# Out:
# Collecting data...
# Data collection complete.
# Collected input sizes: [100, 500, 1000, 2000, 5000, 10000, 20000]
# Collected times: [2.2411346435546875e-05, 2.193450927734375e-05, 6.890296936035156e-05, 0.00017976760864257812, 0.0003075599670410156, 0.0004303455352783203, 0.0009045600891113281]

# %% [markdown]
# ### Plotting the Results
#
# **Subtask**: Create a plot to visualize the relationship between the input size (`n`) and the time taken by the `linear_search` function. This will help us understand its time complexity.
#
# #### Instructions
# 1.  **Import Matplotlib**: Import the `matplotlib.pyplot` library for plotting.
# 2.  **Create the Plot**: Generate a scatter plot or a line plot with `n` values on the x-axis and `times` on the y-axis.
# 3.  **Add Labels and Title**: Label the x-axis as "Input Size (n)", the y-axis as "Time Taken (seconds)", and give the plot a clear title such as "Linear Search Time Complexity".
# 4.  **Display the Plot**: Use `plt.show()` to display the generated graph.

# %% [markdown]
# **Reasoning**:
# The previous step outlined the instructions for plotting the collected data. Now, I will implement the Python code to generate the plot, visualizing the relationship between input size and time taken for the linear search.

# %% [markdown]
# # Task
# Generate Python code to create a plot visualizing the relationship between the collected `sizes` and `times` data for Linear Search, including appropriate labels and a title. Then, review the generated plot and analyze the observed time complexity of Linear Search.

# %% [markdown]
# ## Generate Plotting Code
#
# ### Subtask:
# Write Python code to import `matplotlib.pyplot` and create a plot using the collected `sizes` and `times` data. The plot should visualize the relationship between input size and time taken, including appropriate labels, a title, and a legend.

# %% [markdown]
# **Reasoning**:
# The subtask requires plotting the collected data. I will generate Python code to import `matplotlib.pyplot` and create a scatter plot with appropriate labels and a title, then display it.
